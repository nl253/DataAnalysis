# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./survey.csv")

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
next(df.iterrows()) # show the first item
# Out:
# (0, Timestamp                    2014-08-27 11:29:31
#  Age                                           37
#  Gender                                    Female
#  Country                            United States
#  state                                         IL
#  self_employed                                NaN
#  family_history                                No
#  treatment                                    Yes
#  work_interfere                             Often
#  no_employees                                6-25
#  remote_work                                   No
#  tech_company                                 Yes
#  benefits                                     Yes
#  care_options                            Not sure
#  wellness_program                              No
#  seek_help                                    Yes
#  anonymity                                    Yes
#  leave                              Somewhat easy
#  mental_health_consequence                     No
# ...

# %%
df[df["treatment"] == "Yes"].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Timestamp</th>
#       <th>Age</th>
#       <th>Gender</th>
#       <th>Country</th>
#       <th>state</th>
#       <th>self_employed</th>
#       <th>family_history</th>
#       <th>treatment</th>
#       <th>work_interfere</th>
#       <th>no_employees</th>
#       <th>...</th>
#       <th>leave</th>
#       <th>mental_health_consequence</th>
#       <th>phys_health_consequence</th>
#       <th>coworkers</th>
#       <th>supervisor</th>
#       <th>mental_health_interview</th>
#       <th>phys_health_interview</th>
#       <th>mental_vs_physical</th>
#       <th>obs_consequence</th>
#       <th>comments</th>
# ...

# %%
print(f"""
Info
---------------------
dimensions: {df.ndim}
size: {df.size}
""")
# Out:
# Info
# ---------------------
# dimensions: 2
# size: 33993

# %%
df.describe() # some general info about the DataFramegtgtjjjjgt
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1.259000e+03</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>7.942815e+07</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>2.818299e+09</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-1.726000e+03</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.700000e+01</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.100000e+01</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>3.600000e+01</td>
#     </tr>
#     <tr>
#       <th>max</th>
# ...

# %%
gendered: pd.core.groupby.DataFrameGroupBy = df.groupby("Gender")

# %%
gendered.groups
# Out:
# {'A little about you': Int64Index([989], dtype='int64'),
#  'Agender': Int64Index([553], dtype='int64'),
#  'All': Int64Index([390], dtype='int64'),
#  'Androgyne': Int64Index([544], dtype='int64'),
#  'Cis Female': Int64Index([83], dtype='int64'),
#  'Cis Male': Int64Index([98, 932], dtype='int64'),
#  'Cis Man': Int64Index([1231], dtype='int64'),
#  'Enby': Int64Index([413], dtype='int64'),
#  'F': Int64Index([  88,   94,  161,  164,  178,  213,  218,  238,  296,  304,  337,
#               345,  370,  373,  374,  379,  414,  431,  447,  521,  540,  648,
#               660,  697,  708,  768,  814,  833,  837,  919,  942, 1009, 1016,
#              1130, 1132, 1145, 1172, 1184],
#             dtype='int64'),
#  'Femake': Int64Index([360], dtype='int64'),
#  'Female': Int64Index([   0,    6,    8,   27,   45,   61,   66,   68,  101,  138,
#              ...
#              1169, 1176, 1182, 1188, 1196, 1201, 1212, 1227, 1230, 1248],
#             dtype='int64', length=121),
# ...

# %%
gendered

# %%
gendered.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Timestamp</th>
#       <th>Age</th>
#       <th>Gender</th>
#       <th>Country</th>
#       <th>state</th>
#       <th>self_employed</th>
#       <th>family_history</th>
#       <th>treatment</th>
#       <th>work_interfere</th>
#       <th>no_employees</th>
#       <th>...</th>
#       <th>leave</th>
#       <th>mental_health_consequence</th>
#       <th>phys_health_consequence</th>
#       <th>coworkers</th>
#       <th>supervisor</th>
#       <th>mental_health_interview</th>
#       <th>phys_health_interview</th>
#       <th>mental_vs_physical</th>
#       <th>obs_consequence</th>
#       <th>comments</th>
# ...
